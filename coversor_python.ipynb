# %%
menuprincipal=int(input("Bienvenido... \n***  ¡MENU PRINCIPAL! *** \n 1. Conviersiones con Pesos  \n 2. Conversiones con Dolares \n 3. Conviersiones con Euros \n 4. Conversiones con Yenes \n 0. Terminar \n ") )

#Declaracion de valores en Pesos
valor_dolar = 4447.00
valor_euro = 4421.17
valor_yen = 30.79

#Declaracion de valores En euros
valor_dolar_e = 1.00
valor_pesos_e = 0.00023
valor_yen_e = 0.0070


#Declaracion de valores enYyenes
valor_dolar_y = 143.15
valor_pesos_y = 0.032
valor_euros_y = 143.55



while menuprincipal !=0:

#####################################################################
# --- PRIMERA OPCION DEL MENU PRINCIPAL -----****PESOS****-------
#####################################################################
  if menuprincipal ==1:
    menuprincipal2=int(input("\n ** CONVERSIONES CON PESOS COLOMBIANOS: ** \n 1. Convierte de Pesos a Dolares \n 2. Convierte de Pesos a Euros \n 3. Convierte de Pesos a Yenes \n 0. Regresar al menu principal  \n") )
    
    while menuprincipal2 !=0:
      
      if menuprincipal2 ==1:
        print("Bienvenido: >> Vas a convertir Pesos a Dolares \n")
        pesoscol = float (input("¿Cuantos pesos tienes? "))
        #Calculo valor dolar
        dolares= (pesoscol / valor_dolar)
        dolares = round(dolares, 2)
        dolares = str( dolares)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ dolares + " Dolares!! ")
        print("__________________________________________________________________ \n")


      elif menuprincipal2 ==2:
        print("Bienvenido: >> Vas a convertir Pesos a Euros \n")
        pesoscol = float (input("¿Cuantos pesos tienes? ")) 
        #Calculo Valor Euro
        euros= pesoscol / valor_euro
        euros = round(euros, 2)
        euros = str(euros)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ euros + " Euros!! ")
        print("__________________________________________________________________ \n")


      elif menuprincipal2 == 3:
        print("Bienvenido: >> Vas a convertir Pesos a Yenes \n")
        pesoscol = float (input("¿Cuantos pesos tienes? "))
        #Calculo Yen
        yenes = pesoscol / valor_yen
        yenes = round(yenes, 2)
        yenes = str(yenes)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ yenes + " Yenes!! ")
        print("__________________________________________________________________ \n")

          
      else:
        print("selecciona una opcion correcta")
      #Retorna el menu secundario para romper el segundo ciclo
      menuprincipal2=int(input("** ¡Sigue convirtiendo tus Pesos!: ** \n 1. Convierte de Pesos a Dolares \n 2. Convierte de Pesos a Euros \n 3. Convierte de Pesos a Yenes \n 0. Regresar al menu principal ") )



#####################################################################
# --- SEGUNDA OPCION DEL MENU PRINCIPAL  ------****DOLARES****------
#####################################################################
  elif menuprincipal ==2:
    menuprincipal2=int(input("\n ** CONVERSIONES CON DOLARES USD: ** \n 1. Convierte de Dolares a Pesos \n 2. Convierte de Dolares a Euros \n 3. Convierte de Dolares a Yenes \n 0. Regresar al menu principal \n ") )

    while menuprincipal2 !=0:

     #Convertir Dolares a Pesos
      if menuprincipal2 ==1:
        print("Bienvenido: >> Vas a convertir Dolares a Pesos \n")
        pesosdol = float (input("¿Cuantos Dolares Americanos tienes? "))
       #Calculo Valor Peso
        pesos= pesosdol * valor_dolar
        pesos = round(pesos, 2)
        pesos = str(pesos)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ pesos + " Pesos!! ")
        print("__________________________________________________________________ \n")


     #Convertir Dolares a Euros
      elif menuprincipal2 == 2:
         print("Bienvenido: >> Vas a convertir Dolares a Euros \n")
         pesosdol = float (input("¿Cuantos Dolares Americanos tienes? "))
        #Calculo Valor Euro
         euros= pesosdol / valor_dolar_e
         euros = round(euros, 2)
         euros = str(euros)
         print("------------------------------------------------------------------ ")
         print("RESULTADO: ¡¡Entonces tienes $"+ euros + " Euros!! ")
         print("__________________________________________________________________ \n")

   
     #Convertir Dolares a Yenes
      elif menuprincipal2 == 3:
         print("Bienvenido: >> Vas a convertir Dolares a Yenes \n")
         pesosdol = float (input("¿Cuantos Dolares Americanos tienes? "))
        #Calculo Valor Yen
         yenes= pesosdol / valor_dolar_y
         yenes = round(yenes, 2)
         yenes = str(yenes)
         print("------------------------------------------------------------------ ")
         print("RESULTADO: ¡¡Entonces tienes $"+ yenes + " Yenes!! ")
         print("__________________________________________________________________ \n")


      else:
        print("selecciona una opcion correcta")

      #Retorna el menu secundario para romper el segundo ciclo
      menuprincipal2=int(input("** ¡Sigue convirtiendo tus Dolares!: ** \n 1. Convierte de Dolares a Pesos \n 2. Convierte de Dolares a Euros \n 3. Convierte de Dolares a Yenes \n 0. Regresar al menu principal  ") )



#####################################################################        
# --- TERCERA OPCION DEL MENU PRINCIPAL   ------****EUROS****------
#####################################################################
  elif menuprincipal ==3:
    menuprincipal2=int(input("\n ** CONVERSIONES CON EUROS: ** \n 1. Convierte de Euros a Pesos \n 2. Convierte de Euros a Dolares \n 3. Convierte de Euros a Yenes \n 0. Regresar al Menu Principal  \n ") )

    while menuprincipal2 != 0:
       
     #Convertir Euros a Pesos
      if menuprincipal2 ==1:
        print("Bienvenido: >> Vas a convertir Euros a Pesos \n")
        eurosingresados = float (input("¿Cuantos Euros tienes? "))
       #Calculo Valor Peso
        pesos= eurosingresados * valor_euro
        pesos = round(pesos, 2)
        pesos = str(pesos)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ pesos + " Pesos!! ")
        print("__________________________________________________________________ \n")


     #Convertir Euros a Dolares
      elif menuprincipal2 ==2:
        print("Bienvenido: >> Vas a convertir Euros a Dolares \n")
        eurosingresados = float (input("¿Cuantos Euros tienes? "))
       #Calculo Valor Dolar
        dolares= eurosingresados * valor_dolar_e
        dolares = round(dolares, 2)
        dolares = str(dolares)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ dolares + " Dolares!! ")
        print("__________________________________________________________________ \n")


     #Convertir Euros a Yenes
      elif menuprincipal2 ==3:
        print("Bienvenido: >> Vas a convertir Euros a Yenes \n")
        eurosingresados = float (input("¿Cuantos Euros tienes? "))
       #Calculo Valor Yen
        yenes= eurosingresados * valor_euros_y
        yenes = round(yenes, 2)
        yenes = str(yenes)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ yenes + " Yenes!! ")
        print("__________________________________________________________________ \n")


      else:
        print("selecciona una opcion correcta")

      #Retorna el menu secundario para romper el segundo ciclo
      menuprincipal2=int(input("** ¡Sigue convirtiendo tus Euros!: ** \n 1. Convierte de Euros a Pesos \n 2. Convierte de Euros a Dolares \n 3. Convierte de Euros a Yenes \n 0. Regresar al menu principal ") )



#####################################################################
# --- CUARTA OPCION DEL MENU PRINCIPAL   ------****YENES****------
#####################################################################
  elif menuprincipal ==4:
    menuprincipal2=int(input("\n ** CONVERSIONES CON YENES: ** \n 1. Convierte de Yenes a Pesos \n 2. Convierte de Yenes a Dolares \n 3. Convierte de Yenes a Euros \n 0. Regresar al Menu Principal  \n ") )

    while menuprincipal2 != 0:
       
     #Convertir Yenes a Pesos
      if menuprincipal2 ==1:
        print("Bienvenido: >> Vas a convertir Yenes a Pesos \n")
        yenesingresados = float (input("¿Cuantos Yenes tienes? "))
      
       #Calculo Valor Peso
        pesos= yenesingresados * valor_yen
        pesos = round(pesos, 2)
        pesos = str(pesos)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ pesos + " Pesos!! ")
        print("__________________________________________________________________ \n")

     #Convertir Yenes a Dolares
      elif menuprincipal2 ==2:
        print("Bienvenido: >> Vas a convertir Yenes a Dolares \n")
        yenesingresados = float (input("¿Cuantos Yenes tienes? "))
      
       #Calculo Valor DOlar
        dolares= yenesingresados * valor_dolar_y
        dolares = round(dolares, 2)
        dolares = str(dolares)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ dolares + " Dolares!! ")
        print("__________________________________________________________________ \n")
      
     #Convertir Yenes a Euros
      elif menuprincipal2 ==3:
        print("Bienvenido: >> Vas a convertir Yenes a Euros \n")
        yenesingresados = float (input("¿Cuantos Yenes tienes? "))
       
       #Calculo Valor Euro
        euros= yenesingresados * valor_euros_y
        eruos = round(euros, 2)
        euros = str(euros)
        print("------------------------------------------------------------------ ")
        print("RESULTADO: ¡¡Entonces tienes $"+ euros + " Euros!! ")
        print("__________________________________________________________________ \n")

      else:
        print("selecciona una opcion correcta")

      #Retorna el menu secundario para romper el segundo ciclo 
      menuprincipal2=int(input("** ¡Sigue convirtiendo tus Yenes!: ** \n 1. Convierte de Yenes a Pesos \n 2. Convierte de Yenes a Dolares \n 3. Convierte de Yenes a Euros \n 0. Regresar al Menu Principal  \n ") )

        

  else:
    print("selecciona una opcion correcta")

  #Retorna la menu principal para romper el ciclo   
  menuprincipal=int(input(" \n ***MENU PRINCIPAL*** \n 1. Conviersiones con Pesos  \n 2. Conversiones con Dolares \n 3. Conviersiones con Euros \n 4. Conversiones con Yenes \n 0. Terminar \n ") )

print(" \n Gracias por estar aquí. !Vuelve pronto¡")

#--Repositorio en Git. 
#--Miller Jaramillo Prado
#--Ingeniero de Software
